# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-e0c91b1e5d78> in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv")
#       3 df
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
# ...

# %%
# df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv",skiprows=1)
# df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv",header=1)#header=None
# header1 really means row2 in csv file

df
# Out:
#      1/24/2015  38  23  52  30.03  10     8     0  5 Unnamed: 9  281
# 0   01-02-2016  36  18  46  30.02  10   7.0     0  3        NaN  275
# 1   01-03-2016  40  21  47  29.86  10   8.0     0  1        NaN  277
# 2   01-04-2016  25   9  44  30.05  10   9.0     0  3        NaN  345
# 3   01-05-2016  20  -3  41  30.57  10   5.0     0  0        NaN  333
# 4   01-06-2016  33   4  35  30.50  10   4.0     0  0        NaN  259
# 5   01-07-2016  39  11  33  30.28  10   2.0     0  3        NaN  293
# 6   01-08-2016  39  29  64  30.20  10   4.0     0  8        NaN   79
# 7   01-09-2016  44  38  77  30.16   9   8.0     T  8       Rain   76
# 8   01-10-2016  50  46  71  29.59   4   NaN   1.8  7       Rain  109
# 9   01-11-2016  33   8  37  29.92  10   NaN     0  1        NaN  289
# 10  01-12-2016  35  15  53  29.85  10   6.0     T  4        NaN  235
# 11   1/13/2016  26   4  42  29.94  10  10.0     0  0        NaN  284
# 12   1/14/2016  30  12  47  29.95  10   5.0     T  7        NaN  266
# ...

# %%
# df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv",skiprows=1)
df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv",header=None,names=["a","b","c","d","e","a1","b1","c1","d1","e1","i"])
# header1 really means row2 in csv file

df
# Out:
#              a            b         c         d                     e  \
# 0          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn
# 1    1/24/2015           38        23        52                 30.03
# 2   01-02-2016           36        18        46                 30.02
# 3   01-03-2016           40        21        47                 29.86
# 4   01-04-2016           25         9        44                 30.05
# 5   01-05-2016           20        -3        41                 30.57
# 6   01-06-2016           33         4        35                  30.5
# 7   01-07-2016           39        11        33                 30.28
# 8   01-08-2016           39        29        64                  30.2
# 9   01-09-2016           44        38        77                 30.16
# 10  01-10-2016           50        46        71                 29.59
# 11  01-11-2016           33         8        37                 29.92
# ...

# %%
df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv",nrows=3)
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   1/24/2015           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  Events  \
# 0               10             8                0           5     NaN
# 1               10             7                0           3     NaN
# 2               10             8                0           1     NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\sample_csv.csv",na_values={'Events':["Snow","Rain"]})
                                                                       
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/24/2015           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/24/2015           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
#cpy samplt_csv.csv to new.csv
df.to_csv("C:\\Users\\LENOVO\\Desktop\\new.csv")

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
# df.to_csv("C:\\Users\\LENOVO\\Desktop\\new.csv",columns=["EST"])
df.to_csv("C:\\Users\\LENOVO\\Desktop\\new1.csv",header=False)

# %%
import pandas as pd
df.to_excel("C:\\Users\\LENOVO\\Desktop\\new.xlsx")
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/24/2015           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
import pandas as pd
def convert(ce):
    if ce=="T":
        return "Tem"
    return ce

        
df=pd.read_excel("C:\\Users\\LENOVO\\Desktop\\new.xlsx",converters={
    'PrecipitationIn':convert
                                                                       })
df
# Out:
#     Unnamed: 0         EST  Temperature  DewPoint  Humidity  \
# 0            0   1/24/2015           38        23        52
# 1            1  01-02-2016           36        18        46
# 2            2  01-03-2016           40        21        47
# 3            3  01-04-2016           25         9        44
# 4            4  01-05-2016           20        -3        41
# 5            5  01-06-2016           33         4        35
# 6            6  01-07-2016           39        11        33
# 7            7  01-08-2016           39        29        64
# 8            8  01-09-2016           44        38        77
# 9            9  01-10-2016           50        46        71
# 10          10  01-11-2016           33         8        37
# 11          11  01-12-2016           35        15        53
# 12          12   1/13/2016           26         4        42
# 13          13   1/14/2016           30        12        47
# 14          14   1/15/2016           43        31        62
# ...
