# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\pandas_csv\\pandas_csv1.csv")
# df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\pandas_csv\\pandas_csv1.csv",index_col="Humidity")

df
# Out:
#                  EST  Temperature  DewPoint  Sea Level PressureIn  \
# Humidity
# 52        01-01-2016           38        23                 30.03
# 46        01-02-2016           36        18                 30.02
# 47        01-03-2016           40        21                 29.86
# 44        01-04-2016           25         9                 30.05
# 41        01-05-2016           20        -3                 30.57
# 35        01-06-2016           33         4                 30.50
# 33        01-07-2016           39        11                 30.28
# 64        01-08-2016           39        29                 30.20
# 77        01-09-2016           44        38                 30.16
# 71        01-10-2016           50        46                 29.59
# 37        01-11-2016           33         8                 29.92
# 53        01-12-2016           35        15                 29.85
# 42         1/13/2016           26         4                 29.94
# ...

# %%
df["Temperature"]
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
# df.loc[0:5]
# df.loc[5]
df.iloc[0:5]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
#Third method by using dictionaries
import pandas as pd
student_data={
    'Name':['shaiksha','vivek','anil','kesava','sudhakar','abhisek'],
    'Maths':[78,57,35,98,56,73],
    'physcis':[67,98,23,45,87,99],
    'chemistry'    :[89,67,47,34,66,98],
    'biology':[99,56,73,34,67,23]       
}
df=pd.DataFrame(student_data)
df

# %%
#Fourth Method by using list of tuples
weather=[
    ('a',1,2,"hello"),
    ("b",23,45,"hello2"),
    ("c",34,89,"hello3")
]
df=pd.DataFrame(weather,columns=["alphabetics","no1","no2","events"])
df
# Out:
#   alphabetics  no1  no2  events
# 0           a    1    2   hello
# 1           b   23   45  hello2
# 2           c   34   89  hello3

# %%
#list of tuples 
student_data=[
    {"name":"a","maths":34},
    {"name":"b","maths":334},
    {"name":"c","maths":344},
]
df=pd.DataFrame(student_data)
